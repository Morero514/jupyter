# %%
import pandas as pd
import numpy as np
from pandas import Series
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
from sklearn.model_selection import train_test_split
train, test = train_test_split(dataset,test_size=.15)
from sklearn.linear_model import LinearRegression
sns.set()

# %%
python -m pip install xgboost
# Out:
#   File "<ipython-input-52-0bff454f199f>", line 1
#     python -m pip install xgboost
#                 ^
# SyntaxError: invalid syntax

# %%
dataset=pd.read_csv("C:/Users/mckayla mohobela/Desktop/OnlineRetail.csv",encoding='unicode_escape')

# %%
dataset.head(50)
# Out:
#                InvoiceNo StockCode                          Description  \
# InvoiceDate
# 12/1/2010 8:26    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 12/1/2010 8:26    536365     71053                  WHITE METAL LANTERN
# 12/1/2010 8:26    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 12/1/2010 8:26    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 12/1/2010 8:26    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# 12/1/2010 8:26    536365     22752         SET 7 BABUSHKA NESTING BOXES
# 12/1/2010 8:26    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 12/1/2010 8:28    536366     22633               HAND WARMER UNION JACK
# 12/1/2010 8:28    536366     22632            HAND WARMER RED POLKA DOT
# 12/1/2010 8:34    536367     84879        ASSORTED COLOUR BIRD ORNAMENT
# 12/1/2010 8:34    536367     22745           POPPY'S PLAYHOUSE BEDROOM
# 12/1/2010 8:34    536367     22748            POPPY'S PLAYHOUSE KITCHEN
# ...

# %%
#question 1
dataset.Description.mode()
# Out:
# 0    WHITE HANGING HEART T-LIGHT HOLDER
# dtype: object

# %%
#question2
dataset[dataset['Country']=='Australia'].groupby(['Description']).sum().sort_values('Quantity',ascending=False)
# Out:
#                                Quantity  UnitPrice  CustomerID
# Description
# MINI PAINT SET VINTAGE             2916       4.15     86921.0
# RABBIT NIGHT LIGHT                 1884      11.03     74522.0
# RED  HARMONICA IN BOX              1704       7.80     86861.0
# RED TOADSTOOL LED NIGHT LIGHT      1344      13.85    111793.0
# DOLLY GIRL LUNCH BOX               1024       9.90     74490.0
# ...                                 ...        ...         ...
# TOADSTOOL BEDSIDE LIGHT               0      17.90     24862.0
# POSTAGE                               0     612.73     24830.0
# SPACEBOY CHILDRENS CUP                0       2.50     24830.0
# JIGSAW TOADSTOOLS 3 PIECE             0       3.30     24868.0
# RED RETROSPOT TISSUE BOX             -5       1.25     12434.0
#
# [609 rows x 3 columns]

# %%
#question 3
dataset.InvoiceDate.mode('InvoiceDate')
# Out:
# 0    10/31/2011 14:41
# dtype: object

# %%
#question 4
nk=dataset.groupby('Country').CustomerID.value_counts()>1
nk.sum()
# Out:
# 4301

# %%
#question 5
dataset[dataset['Description']=='SPACEBOY BIRTHDAY CARD'].groupby(['Country']).sum().sort_values('Quantity',ascending=False)
# Out:
#                  Quantity  UnitPrice  CustomerID
# Country
# United Kingdom       4921     235.62   4488761.0
# Netherlands          1884       6.18    247095.0
# France                372      11.76    354060.0
# Australia             300       1.50     49676.0
# Germany               288       9.24    275881.0
# Switzerland           168       4.62    128511.0
# Belgium               108       3.78    111589.0
# Austria                36       1.26     38090.0
# Spain                  36       1.26     37564.0
# EIRE                   24       0.84     29822.0
# Channel Islands        12       0.42     14930.0
# Finland                12       0.42     12428.0
# Greece                 12       0.42     12478.0
# USA                     0       0.84     25214.0

# %%
#question 6
Avg = dataset.groupby('InvoiceNo',as_index=False)['Quantity'].sum()
Avg = Avg.sort_values(by='Quantity',ascending=False)
New_dataset=pd.DataFrame()
New_dataset=dataset = Avg.mean()
New_dataset
# Out:
# Quantity    199.862934
# dtype: float64

# %%
dataset=dataset.set_index('InvoiceDate')
dataset.head(5)
# Out:
#                InvoiceNo StockCode                          Description  \
# InvoiceDate
# 12/1/2010 8:26    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 12/1/2010 8:26    536365     71053                  WHITE METAL LANTERN
# 12/1/2010 8:26    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 12/1/2010 8:26    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 12/1/2010 8:26    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#                 Quantity  UnitPrice  CustomerID         Country
# InvoiceDate
# 12/1/2010 8:26         6       2.55     17850.0  United Kingdom
# 12/1/2010 8:26         6       3.39     17850.0  United Kingdom
# 12/1/2010 8:26         8       2.75     17850.0  United Kingdom
# 12/1/2010 8:26         6       3.39     17850.0  United Kingdom
# 12/1/2010 8:26         6       3.39     17850.0  United Kingdom

# %%
#question 8
dataset[dataset['Description']=='PINK CAT BOWL'].groupby(['Country']).sum().sort_values('Quantity',ascending=False)
# Out:
#                 Quantity  UnitPrice  CustomerID  Average_purchases_per_invoice
# Country
# United Kingdom       359     213.69    594989.0                            0.0
# Unspecified            1       2.10     12743.0                            0.0

# %%
#question 8
ck=dataset[dataset['Description']=='PINK CAT BOWL']
ck.CustomerID.nunique()
# Out:
# 30

# %%
#question 8
ck=dataset[dataset['Description']=='PINK CAT BOWL'].groupby('Country')
ck.CustomerID.nunique()
# Out:
# Country
# United Kingdom    29
# Unspecified        1
# Name: CustomerID, dtype: int64

# %%
dataset[dataset['Description']=='ALARM CLOCK'].groupby(['Country']).sum().sort_values('Quantity',ascending=False)
# Out:
# Empty DataFrame
# Columns: [Quantity, UnitPrice, CustomerID, Average_purchases_per_invoice]
# Index: []

# %%
#question 9
dataset['InvoiceDate'] = pd.to_datetime(dataset['InvoiceDate'])
dataset['date'] = dataset['InvoiceDate'].dt.date
dataset['time'] = dataset['InvoiceDate'].dt.time

# %%
time = dataset.loc[dataset.Description.str.contains(pat = 'CHRISTMAS', na = False)]
time
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 46        536371     22086   PAPER CHAIN KIT 50'S CHRISTMAS         80
# 122       536381     22086   PAPER CHAIN KIT 50'S CHRISTMAS          4
# 172       536385    85049A     TRADITIONAL CHRISTMAS RIBBONS        12
# 197       536389     22941      CHRISTMAS LIGHTS 10 REINDEER         6
# 211       536390     22941      CHRISTMAS LIGHTS 10 REINDEER         2
# ...          ...       ...                               ...       ...
# 541840    581580     21803    CHRISTMAS TREE STAR DECORATION         2
# 541841    581580     21809  CHRISTMAS HANGING TREE WITH BELL         2
# 541844    581580    85049A     TRADITIONAL CHRISTMAS RIBBONS         1
# 541847    581580     22144    CHRISTMAS CRAFT LITTLE FRIENDS         1
# 541854    581580     22075      6 RIBBONS ELEGANT CHRISTMAS          2
#
#                InvoiceDate  UnitPrice  CustomerID         Country        date  \
# ...

# %%
#question 9
time.time.mode()
# Out:
# 0    14:41:00
# dtype: object

# %%
#question 10
cancelled_order = dataset[dataset.InvoiceNo.str.contains("C")]
cancelled_order.head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#          InvoiceDate  UnitPrice  CustomerID         Country
# 141   12/1/2010 9:41      27.50     14527.0  United Kingdom
# 154   12/1/2010 9:49       4.65     15311.0  United Kingdom
# 235  12/1/2010 10:24       1.65     17548.0  United Kingdom
# 236  12/1/2010 10:24       0.29     17548.0  United Kingdom
# 237  12/1/2010 10:24       0.29     17548.0  United Kingdom

# %%
cancelled_order.Country.mode()
# Out:
# 0    United Kingdom
# dtype: object

# %%
#question 10
cancelled_order.Country.min()
# Out:
# 'Australia'

# %%
#question 10
cancelled_order.Country.max()
# Out:
# 'United Kingdom'

# %%
#question 11
DATA = dataset.loc[dataset.Description.str.contains(pat = 'ALARM CLOCK', na = False)]
DATA
# Out:
#        InvoiceNo StockCode                 Description  Quantity  \
# 26        536370     22728   ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727   ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726  ALARM CLOCK BAKELIKE GREEN        12
# 149       536382     22726  ALARM CLOCK BAKELIKE GREEN         4
# 205       536389     22726  ALARM CLOCK BAKELIKE GREEN         4
# ...          ...       ...                         ...       ...
# 541880    581585     22727   ALARM CLOCK BAKELIKE RED          4
# 541897    581587     22728   ALARM CLOCK BAKELIKE PINK         4
# 541898    581587     22727   ALARM CLOCK BAKELIKE RED          4
# 541899    581587     22726  ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730  ALARM CLOCK BAKELIKE IVORY         4
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 26       12/1/2010 8:45       3.75     12583.0          France
# ...

# %%
#question 11
DATA.Country.mode()
# Out:
# 0    United Kingdom
# dtype: object

# %%
#question 12
p_france = dataset[(dataset["Country"]=="Portugal")]
p_france.head(3)
# Out:
#      InvoiceNo StockCode                     Description  Quantity  \
# 7134    536990     21992  VINTAGE PAISLEY STATIONERY SET         6
# 7135    536990     22383         LUNCH BAG SUKI  DESIGN         10
# 7136    536990     20728             LUNCH BAG CARS BLUE        14
#
#           InvoiceDate  UnitPrice  CustomerID   Country
# 7134  12/3/2010 15:14       2.95     12793.0  Portugal
# 7135  12/3/2010 15:14       1.65     12793.0  Portugal
# 7136  12/3/2010 15:14       1.65     12793.0  Portugal

# %%
#question 12
timeindex = p_france.set_index('InvoiceDate')
timeindex.index
# Out:
# Index(['12/3/2010 15:14', '12/3/2010 15:14', '12/3/2010 15:14',
#        '12/3/2010 15:14', '12/3/2010 15:14', '12/3/2010 15:14',
#        '12/3/2010 15:14', '12/6/2010 10:27', '12/6/2010 10:27',
#        '12/6/2010 10:27',
#        ...
#        '12/7/2011 15:56', '12/7/2011 15:56', '12/7/2011 15:56',
#        '12/7/2011 15:56', '12/7/2011 15:56', '12/7/2011 15:56',
#        '12/7/2011 15:56', '12/7/2011 15:56', '12/7/2011 15:56',
#        '12/7/2011 15:56'],
#       dtype='object', name='InvoiceDate', length=1519)

# %%
#question 12
p_portugal = dataset[(dataset["Country"]=="France")]
p_portugal.head(3)
# Out:
#    InvoiceNo StockCode                 Description  Quantity     InvoiceDate  \
# 26    536370     22728   ALARM CLOCK BAKELIKE PINK        24  12/1/2010 8:45
# 27    536370     22727   ALARM CLOCK BAKELIKE RED         24  12/1/2010 8:45
# 28    536370     22726  ALARM CLOCK BAKELIKE GREEN        12  12/1/2010 8:45
#
#     UnitPrice  CustomerID Country
# 26       3.75     12583.0  France
# 27       3.75     12583.0  France
# 28       3.75     12583.0  France

# %%
#question 12
timeindex = p_portugal.set_index('InvoiceDate')
timeindex.index
# Out:
# Index(['12/1/2010 8:45', '12/1/2010 8:45', '12/1/2010 8:45', '12/1/2010 8:45',
#        '12/1/2010 8:45', '12/1/2010 8:45', '12/1/2010 8:45', '12/1/2010 8:45',
#        '12/1/2010 8:45', '12/1/2010 8:45',
#        ...
#        '12/9/2011 12:50', '12/9/2011 12:50', '12/9/2011 12:50',
#        '12/9/2011 12:50', '12/9/2011 12:50', '12/9/2011 12:50',
#        '12/9/2011 12:50', '12/9/2011 12:50', '12/9/2011 12:50',
#        '12/9/2011 12:50'],
#       dtype='object', name='InvoiceDate', length=8557)

# %%
#create reference table of item code and its description
unique_indexes = dataset.StockCode.drop_duplicates().index
dataset[['StockCode','Description']].loc[unique_indexes]
ref_stock_desc = dataset[['StockCode','Description']].loc[unique_indexes]#the ref table
ref_stock_desc_index = range(len(ref_stock_desc))

# %%
df_quant_sold = dataset[['StockCode','Quantity']].groupby('StockCode').sum()
df_quant_sold.reset_index(inplace = True)
#order descending
df_quant_sold.sort_values(by = ['Quantity'], ascending = False, inplace = True)
#merge
df_quant_sold = df_quant_sold.merge(ref_stock_desc, on = 'StockCode')

# %%
df_quant_sold.iloc[:5].plot.bar(x = 'Description', y = 'Quantity',
                                color = 'skyblue',
                                title = 'top 5 Purchased products by Quantity')

# %%
df_quant_sold.iloc[:5].plot.hist(x = 'Description', y = 'Quantity',
                                color = 'skyblue',
                                title = 'top 5 Purchased products by Quantity')

# %%
train_prophet = dataset[['StockCode','Quantity']].groupby('StockCode').sum()
#creating a train dataset
train_prophet = train.copy()
train_prophet.reset_index(level=0, inplace=True)
#converting col name to specific names as requierd by prophet library
train_prophet = dataset.rename(columns ={'date': 'dd','Sales': 'y'})

# %% [raw]
# dataset = read_csv('OnlineRetail.csv', header=None,index_col=0,parse_dates=True,squeeze=True)
# dataset.plot()
# pyplot.show()

# %%
per_day = dataset.groupby('InvoiceDate',as_index=False)['UnitPrice'].sum()
per_day
# Out:
#            InvoiceDate  UnitPrice
# 0      1/10/2011 10:04       0.00
# 1      1/10/2011 10:07       3.75
# 2      1/10/2011 10:08       0.00
# 3      1/10/2011 10:32      44.22
# 4      1/10/2011 10:35      53.28
# ...                ...        ...
# 23255    9/9/2011 8:48      80.95
# 23256    9/9/2011 9:03      39.17
# 23257    9/9/2011 9:13     167.88
# 23258    9/9/2011 9:38      70.37
# 23259    9/9/2011 9:52      85.42
#
# [23260 rows x 2 columns]

# %%
print(len(train))
# Out:
# 460622

# %%
print(len(test))
# Out:
# 81287

# %%
#question 13
train_predictors = train.drop(['StockCode','UnitPrice','CustomerID'],axis=1)
train_target = train.drop(list(train_predictors)+['StockCode','UnitPrice','CustomerID'],axis=1)

# %%
test_predictors = test.drop(['InvoiceNo','UnitPrice','CustomerID'],axis=1)
test_target = test.drop(list(test_predictors)+['StockCode','UnitPrice','CustomerID'],axis=1)

# %%
print(train_predictors.head(5))
# Out:
#        InvoiceNo                         Description  Quantity  \
# 444055    574719      CHRISTMAS RETROSPOT ANGEL WOOD        12
# 327359    565664          12 COLOURED PARTY BALLOONS         9
# 194386    553575                      SPOTTY BUNTING         6
# 377762    569564             CREAM HEART CARD HOLDER         4
# 210404    555278  TRADITIONAL WOODEN CATCH CUP GAME          1
#
#             InvoiceDate         Country
# 444055  11/6/2011 14:38  United Kingdom
# 327359   9/5/2011 17:36  United Kingdom
# 194386  5/18/2011 10:08  United Kingdom
# 377762   10/5/2011 9:47  United Kingdom
# 210404   6/1/2011 17:33  United Kingdom

# %%
print(train_target.head(5))
# Out:
# Empty DataFrame
# Columns: []
# Index: [444055, 327359, 194386, 377762, 210404]

# %%
#question 14
from sklearn.linear_model import LinearRegression
lr = LinearRegression(normalize=True)
lr.fit(train_predictors,train_target)
train_predictions=lr.predict(train_predictors)
train_predictions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-021ff52b04da> in <module>
#       2 from sklearn.linear_model import LinearRegression
#       3 lr = LinearRegression(normalize=True)
# ----> 4 lr.fit(train_predictors,train_target)
#       5 train_predictions=lr.predict(train_predictors)
#       6 train_predictions
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
plt.hist(dataset.Quantity, bins = 4)
plt.xlabel('iterms per sales')
plt.ylabel('Number of sales')
plt.title('Top 5 Purchased product by Quantity')
display(plt.show())
# Out:
# None

# %%
plt.figure()
sns.pairplot(dataset)
display(plt.show())
# Out:
# None

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-343e41110c76> in <module>
#       2
#       3 lr = LinearRegression(normalize=True)
# ----> 4 lr.fit(train_predictors,train_target)
#       5
#       6 train_predictions=lr.predict(train_predictors)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
#question 13
xg_model = xgb.XGBRegressor(n_estimators=1000, learning_rate=0.05)
xg_model.fit(train_predictors, train_target)

xg_train_predictions = xg_model.predict(train_predictors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-36ed43872319> in <module>
# ----> 1 xg_model = xgb.XGBRegressor(n_estimators=1000, learning_rate=0.05)
#       2 xg_model.fit(train_predictors, train_target)
#       3
#       4 xg_train_predictions = xg_model.predict(train_predictors)
#
# NameError: name 'xgb' is not defined

# %%
plt.figure()
plt.scatter(dataset,train_predictions)
plt.xlable("Quantity")
plt.ylabel("Description")
plt.title("Online Retail")
display(plt.show())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-9ff33d54143a> in <module>
#       1 plt.figure()
# ----> 2 plt.scatter(dataset,train_predictions)
#       3 plt.xlable("Quantity")
#       4 plt.ylabel("Description")
#       5 plt.title("Online Retail")
#
# NameError: name 'train_predictions' is not defined

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression(normalize=True)
lr.fit(train_predictors,train_target)

train_predictions=lr.predict(train_predictors)

train_predictions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-1885ac6ccfc5> in <module>
#       2
#       3 lr = LinearRegression(normalize=True)
# ----> 4 lr.fit(train_predictors,train_target)
#       5
#       6 train_predictions=lr.predict(train_predictors)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...
